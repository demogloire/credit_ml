# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('train_u6lujuX_CVtuZ9i.csv')

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
df=data.copy()

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
#Identification du variable cible
df['Loan_Status']
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
#Etudes de dimension du dataset
df.shape
# Out:
# (614, 13)

# %%
df.dtypes.value_counts()
# Out:
# object     8
# float64    4
# int64      1
# dtype: int64

# %%
#Etude des valeurs manquantes
df.isna()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# 1              False              False       False             False
# 2              False              False       False             False
# 3              False              False       False             False
# 4              False              False       False             False
# ..               ...                ...         ...               ...
# 609            False              False       False             False
# 610            False              False       False             False
# 611            False              False       False             False
# 612            False              False       False             False
# 613            False              False       False             False
#
#      Credit_History  Property_Area  Loan_Status
# 0             False          False        False
# 1             False          False        False
# 2             False          False        False
# 3             False          False        False
# 4             False          False        False
# ..              ...            ...          ...
# 609           False          False        False
# 610           False          False        False
# 611           False          False        False
# 612           False          False        False
# 613           False          False        False
#
# [614 rows x 13 columns]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)

# %%
((df.isna().sum()/df.shape[0])*100).sort_values(ascending=False)
# Out:
# Credit_History       8.143322
# Self_Employed        5.211726
# LoanAmount           3.583062
# Dependents           2.442997
# Loan_Amount_Term     2.280130
# Gender               2.117264
# Married              0.488599
# Loan_Status          0.000000
# Property_Area        0.000000
# CoapplicantIncome    0.000000
# ApplicantIncome      0.000000
# Education            0.000000
# Loan_ID              0.000000
# dtype: float64

# %%
df.columns[((df.isna().sum()/df.shape[0])*100) > 5]
# Out:
# Index(['Self_Employed', 'Credit_History'], dtype='object')

# %%
#Etudes du target
df['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
#Etudes des autres variables: Variables continues

# %%
# fonction d'affichage des colonnes des histogrames
def displot_data(dataframe, type_colonne):
    if type_colonne =='object':
        print("Aucun affichage")
    else:
        for col in dataframe.select_dtypes(type_colonne):  # select_dtypes nous aide à selectionner les variables
            plt.figure()
            sns.distplot(dataframe[col])

# %%
displot_data(df,'float')
# Out:
# C:\Users\Demo 8\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
# Etudes variables catégorielles

# %%
for col in df.select_dtypes('object'):
    if col !='Loan_ID':
        print(f'{col :-<50} {df[col].unique()}')
# Out:
# Gender-------------------------------------------- ['Male' 'Female' nan]
# Married------------------------------------------- ['No' 'Yes' nan]
# Dependents---------------------------------------- ['0' '1' '2' '3+' nan]
# Education----------------------------------------- ['Graduate' 'Not Graduate']
# Self_Employed------------------------------------- ['No' 'Yes' nan]
# Property_Area------------------------------------- ['Urban' 'Rural' 'Semiurban']
# Loan_Status--------------------------------------- ['Y' 'N']

# %%
for col in df.select_dtypes('object'):
    if col != 'Loan_ID':
        plt.figure()
        df[col].value_counts().plot.pie()

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
sns.pairplot(df)

# %%
les_variables_categorielle=[]
les_variables_continue=[]

# %%
for col in df.select_dtypes(['int','float']):
    les_variables_continue.append(col)

for col in df.select_dtypes('object'):
    if col != 'Loan_ID':
        les_variables_categorielle.append(col)

# %%
les_variables_categorielle
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
les_variables_continue
# Out:
# ['CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %%
df[les_variables_continue]
# Out:
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
# [614 rows x 4 columns]

# %%
pd.crosstab(df['Education'], df['Property_Area'])
# Out:
# Property_Area  Rural  Semiurban  Urban
# Education
# Graduate         131        187    162
# Not Graduate      48         46     40

# %%
from scipy.stats import ttest_ind

# %%
credit_accepter=df[df['Loan_Status']=='Y']
credit_refuser=df[df['Loan_Status']=='N']

# %%
credit_accepter.shape
# Out:
# (422, 13)

# %%
credit_refuser.shape
# Out:
# (192, 13)

# %%
credit_accepter.sample(192)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 101  LP001349    Male      No          0      Graduate            No
# 248  LP001824    Male     Yes          1      Graduate            No
# 224  LP001750    Male     Yes          0      Graduate            No
# 594  LP002938    Male     Yes          0      Graduate           Yes
# 392  LP002263    Male     Yes          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 306  LP001993  Female      No          0      Graduate            No
# 593  LP002936    Male     Yes          0      Graduate            No
# 253  LP001843    Male     Yes          1  Not Graduate            No
# 433  LP002387    Male     Yes          0      Graduate            No
# 317  LP002036    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 101             4843             3806.0       151.0             360.0
# 248             2882             1843.0       123.0             480.0
# 224             6250                0.0       128.0             360.0
# 594            16120                0.0       260.0             360.0
# 392             2583             2115.0       120.0             360.0
# ..               ...                ...         ...               ...
# 306             3762             1666.0       135.0             360.0
# 593             3859             3300.0       142.0             180.0
# 253             2661             7101.0       279.0             180.0
# 433             2425             2340.0       143.0             360.0
# 317             2058             2134.0        88.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 101             1.0     Semiurban           Y
# 248             1.0     Semiurban           Y
# 224             1.0     Semiurban           Y
# 594             1.0         Urban           Y
# 392             NaN         Urban           Y
# ..              ...           ...         ...
# 306             1.0         Rural           Y
# 593             1.0         Rural           Y
# 253             1.0     Semiurban           Y
# 433             1.0     Semiurban           Y
# 317             NaN         Urban           Y
#
# [192 rows x 13 columns]

# %%
credit_accepter.sample(credit_rejetter.shape[0])
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 264  LP001872    Male      No          0      Graduate           Yes
# 579  LP002888    Male      No          0      Graduate           NaN
# 331  LP002098    Male      No          0      Graduate            No
# 348  LP002137    Male     Yes          0      Graduate            No
# 342  LP002119    Male     Yes          1  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 160  LP001560    Male     Yes          0  Not Graduate            No
# 89   LP001310    Male     Yes          0      Graduate            No
# 125  LP001443  Female      No          0      Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 526  LP002705    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 264             5166                0.0       128.0             360.0
# 579             3182             2917.0       161.0             360.0
# 331             2935                0.0        98.0             360.0
# 348             6333             4583.0       259.0             360.0
# 342             4554             1229.0       158.0             360.0
# ..               ...                ...         ...               ...
# 160             1863             1041.0        98.0             360.0
# 89              5695             4167.0       175.0             360.0
# 125             3692                0.0        93.0             360.0
# 4               6000                0.0       141.0             360.0
# 526             3775                0.0       110.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 264             1.0     Semiurban           Y
# 579             1.0         Urban           Y
# 331             1.0     Semiurban           Y
# 348             NaN     Semiurban           Y
# 342             1.0         Urban           Y
# ..              ...           ...         ...
# 160             1.0     Semiurban           Y
# 89              1.0     Semiurban           Y
# 125             NaN         Rural           Y
# 4               1.0         Urban           Y
# 526             1.0     Semiurban           Y
#
# [192 rows x 13 columns]

# %%
# Test de Student:

def t_test(col):
    alpha= 0.05
    stat, p = ttest_ind(credit_accepter.sample(credit_rejetter.shape[0])[col].dropna(), credit_rejetter[col].dropna())
    
    if p < alpha:
        return 'H0 Rejetée'
    else:
        return 0

# %%
for col in df[les_variables_continue]:
    print(f'{col :-<50} {t_test(col)}')
# Out:
# CoapplicantIncome--------------------------------- 0
# LoanAmount---------------------------------------- 0
# Loan_Amount_Term---------------------------------- 0
# Credit_History------------------------------------ H0 Rejetée

# %% [markdown]
# ## Pré-proccessing

# %% [markdown]
#  * 1. Mettre les données dans un *format* propice au ML
#      - Train / Test
#      - Encodage
#      - Nettoyage des NaN
#          * Premier modele: Evaluation et Diagnostique
#  * 2. *Améliorer* la performance du modele:
#      - Feature Selection
#      - Feature Engineering
#      - Feature Scaling
#      - Suppression des outliers

# %%
df_n=data.copy()

# %%
df_n=df_n.drop('Loan_ID', axis=1)

# %%
df_n
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#     Property_Area Loan_Status
# 0           Urban           Y
# 1           Rural           N
# 2           Urban           Y
# 3           Urban           Y
# 4           Urban           Y
# ..            ...         ...
# 609         Rural           Y
# 610         Rural           Y
# 611         Urban           Y
# 612         Urban           Y
# 613     Semiurban           N
#
# [614 rows x 12 columns]

# %%
#division du dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer

# %%
trainset, testset=train_test_split(df_n, test_size=0.2, random_state=0)

# %%
trainset['Loan_Status'].value_counts()
# Out:
# Y    332
# N    159
# Name: Loan_Status, dtype: int64

# %%
testset['Loan_Status'].value_counts(normalize=True)
# Out:
# Y    0.731707
# N    0.268293
# Name: Loan_Status, dtype: float64

# %%
def imputation(df_n):
    return df_n.dropna(axis=0)
    #return df_n.fillna(-999)

# %%
def preprocessing(df_n):
    df_n=encodage(df_n)
    df_n=imputation(df_n)
    
    X=df_n.drop('Loan_Status', axis=1)
    y=df_n['Loan_Status']
    
    print(y.value_counts())
    return X, y

# %%
X_train, y_train= preprocessing(trainset)
# Out:
# 0    207
# 1     99
# Name: Loan_Status, dtype: int64

# %%
X_test, y_test= preprocessing(testset)
# Out:
# 0    60
# 1    29
# Name: Loan_Status, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif 
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score

# %%
preproccesor=make_pipeline(PolynomialFeatures(2, include_bias=False),  SelectKBest(f_classif, k=10))

# %%
RandomForest=make_pipeline(preproccesor, RandomForestClassifier(random_state=0))
AdaBoost= make_pipeline(preproccesor, AdaBoostClassifier(random_state=0))
svm=make_pipeline(preproccesor, StandardScaler(), SVC(random_state=0))
KNN = make_pipeline(preproccesor, StandardScaler(), KNeighborsClassifier())
logist = make_pipeline(preproccesor, StandardScaler(), LogisticRegression(random_state=0))

# %%
liste_des_modeles={'RandomForest':RandomForest,'AdaBoost':AdaBoost,'svm':svm,'KNN': KNN,'logist':logist}

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve

# %%
 def evaluation(model):
        model.fit(X_train, y_train)
        ypred=model.predict(X_test)
        
        print(confusion_matrix(y_test, ypred))
        print(classification_report(y_test, ypred))
        
        N, train_score, validation_score=learning_curve(model,X_train, y_train, 
                                                        scoring='f1',
                                                        cv=4, 
                                                        train_sizes=np.linspace(0.1,1,10))
        
        plt.figure(figsize=(12,8))
        plt.plot(N, train_score.mean(axis=1), label='Train score')
        plt.plot(N, validation_score.mean(axis=1), label='Validation score')
        plt.legend()

# %%
for nom, model in liste_des_modeles.items():
    print(nom)
    evaluation(model)
# Out:
# RandomForest
# [[54  6]
#  [16 13]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        60
#            1       0.68      0.45      0.54        29
#
#     accuracy                           0.75        89
#    macro avg       0.73      0.67      0.69        89
# weighted avg       0.74      0.75      0.74        89
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# AdaBoost
# [[52  8]
#  [14 15]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83        60
#            1       0.65      0.52      0.58        29
#
#     accuracy                           0.75        89
#    macro avg       0.72      0.69      0.70        89
# weighted avg       0.74      0.75      0.74        89
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# svm
# [[57  3]
#  [15 14]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.86        60
#            1       0.82      0.48      0.61        29
#
#     accuracy                           0.80        89
#    macro avg       0.81      0.72      0.74        89
# weighted avg       0.80      0.80      0.78        89
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# KNN
# [[57  3]
#  [15 14]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.86        60
#            1       0.82      0.48      0.61        29
#
#     accuracy                           0.80        89
#    macro avg       0.81      0.72      0.74        89
# weighted avg       0.80      0.80      0.78        89
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# logist
# [[58  2]
#  [15 14]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.97      0.87        60
#            1       0.88      0.48      0.62        29
#
#     accuracy                           0.81        89
#    macro avg       0.83      0.72      0.75        89
# weighted avg       0.82      0.81      0.79        89
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 42 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [25 34 51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [51] are constant.
#   UserWarning)
# C:\Users\Demo 8\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
svm
# Out:
# Pipeline(memory=None,
#          steps=[('pipeline',
#                  Pipeline(memory=None,
#                           steps=[('polynomialfeatures',
#                                   PolynomialFeatures(degree=2,
#                                                      include_bias=False,
#                                                      interaction_only=False,
#                                                      order='C')),
#                                  ('selectkbest',
#                                   SelectKBest(k=10,
#                                               score_func=<function f_classif at 0x0000000F34F108B8>))],
#                           verbose=False)),
#                 ('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('svc',
#                  SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None,
#                      coef0=0.0, decision_function_shape='ovr', degree=3,
#                      gamma='scale', kernel='rbf', max_iter=-1,
#                      probability=False, random_state=0, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
hyper_params = {'svc__gamma':[1e-3, 1e-4], 'svc__C':[1, 10 , 100, 1000],
               'pipeline__polynomialfeatures__degree':[2,3,4,],'pipeline__selectkbest__k':range(5,10)}

# %%
grid = RandomizedSearchCV(svm, hyper_params,  scoring='accuracy', cv=4)

# %%
grid.fit(X_train, y_train)
print(grid.best_params_)
y_pred=grid.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# {'pipeline__polynomialfeatures__degree': 2, 'pipeline__selectkbest__k': 5, 'svc__C': 1, 'svc__gamma': 0.001}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-840-0b7931377239> in <module>
#       1 grid.fit(X_train, y_train)
#       2 print(grid.best_params_)
# ----> 3 y_pred=grid.predict_proba(X_test)
#       4 print(classification_report(y_test, y_pred))
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in __get__(self, obj, type)
#     108                     continue
#     109                 else:
# --> 110                     getattr(delegate, self.attribute_name)
#     111                     break
#     112             else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in __get__(self, obj, type)
#     108                     continue
#     109                 else:
# --> 110                     getattr(delegate, self.attribute_name)
#     111                     break
#     112             else:
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in predict_proba(self)
#     634         datasets.
#     635         """
# --> 636         self._check_proba()
#     637         return self._predict_proba
#     638
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _check_proba(self)
#     601     def _check_proba(self):
#     602         if not self.probability:
# --> 603             raise AttributeError("predict_proba is not available when "
#     604                                  " probability=False")
#     605         if self._impl not in ('c_svc', 'nu_svc'):
#
# AttributeError: predict_proba is not available when  probability=False

# %%
grid
